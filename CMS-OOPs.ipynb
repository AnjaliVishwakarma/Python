# %%
# CMS
# BLL
class Customer:
    list_cus=[]
    
    def __init__(self):
        self.id=0
        self.name=""
        self.address=""
        self.mobile=""
    
    def __str__(self):
        return "Id:{0}, Name:{1}, Address:{2}, Mobile Number:{3}".format(self.id,self.name,self.address,self.mobile)
    
    def add_cus(self):
        Customer.list_cus.append(cus)
        
    def search_cus(self,cus_id):
        for i in Customer.list_cus:
            if i.id==cus_id:
                self.id=i.id
                self.name=i.name
                self.address=i.address
                self.mobile=i.mobile
                return True
        return False
    
    def modify_cus(self,cus_id):
        for i in Customer.list_cus:
            if i.id == cus_id:
                i.id=self.id
                i.name=self.name
                i.address=self.address
                i.mobile=self.mobile
                return True
        return False
    
    def delete_cus(self,cus_id):
        for i in Customer.list_cus:
            if i.id==cus_id:
                Customer.list_cus.pop(i.id)
                return True
        return False
        
        
    
# PL

# cus = Customer()
while (True):
    print("Enter '1' for add customer,\n'2' for search customer,\n'3' for modify customer,\n'4' for delete customer,\n'5' display all customer,\n'6' for exit")
    ch=input('Enter your choice: ')
    if ch=='1':
        cus = Customer()
        cus.id=int(input('Enter Customer id:'))
        cus.name=input("Enter Customer name: ")
        cus.address=input("Enter Customer address: ")
        cus.mobile=input("Enter Customer mobile number: ")
        cus.add_cus()
        print('Customer added successfully')

    # elif ch=='2':
    #     cus=Customer()
    #     for i in Customer.list_cus:
    #         print(i)

    elif ch=='2':
    #     search customer
        cus=Customer()
        cus.id=int(input('Enter Customer ID: '))
        check=cus.search_cus(cus.id)
        if check==False:
            print("Id not found")
        else:
            print(cus)


    elif ch=='3':
         # modify customer
        cus=Customer()
        cus.id=int(input('Enter Customer ID: '))
        check=cus.modify_cus(cus.id)
        if check==False:
            print("Id not found")
        else:
            print("Customer Modify Successfully")


    elif ch=='4':
    #     delete customer
        cus=Customer()
        cus.id=int(input('Enter Customer ID: '))
        check=cus.delete_cus(cus.id)
        if check==False:
            print("Id not found")
        else:
            print("Customer Deleted Successfully")

    elif ch=='5':
        cus=Customer()
        for i in Customer.list_cus:
            print(i)
    elif ch=='6':
        print('Thankyou for using our CMS')
        break
# Out:
# Enter '1' for add customer,
# '2' for search customer,
# '3' for modify customer,
# '4' for delete customer,
# '5' display all customer,
# '6' for exit
# Enter your choice: 1
# Enter Customer id:1
# Enter Customer name: ram
# Enter Customer address: ds
# Enter Customer mobile number: 65
# Customer added successfully
# Enter '1' for add customer,
# '2' for search customer,
# '3' for modify customer,
# '4' for delete customer,
# '5' display all customer,
# '6' for exit
# Enter your choice: 5
# Id:1, Name:ram, Address:ds, Mobile Number:65
# Enter '1' for add customer,
# '2' for search customer,
# '3' for modify customer,
# '4' for delete customer,
# '5' display all customer,
# '6' for exit
# Enter your choice: 2
# Enter Customer ID: 1
# Id:1, Name:ram, Address:ds, Mobile Number:65
# Enter '1' for add customer,
# '2' for search customer,
# '3' for modify customer,
# '4' for delete customer,
# '5' display all customer,
# '6' for exit
# Enter your choice: 3
# Enter Customer ID: 1
# ...
